# %%
###Inheritance(Single Inheritance)
### Parent class

class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"the person will drive the {self.enginetype} car")

# %%
car1=Car(4,5,"diesel")
car1.drive()
print(car1.drive())
# Out:
# the person will drive the diesel car
# the person will drive the diesel car
# None

# %%
##Inherited Class
class Skoda(Car):
    def __init__(self, windows,doors,enginetype, is_selfdriving):
        super().__init__(windows,doors,enginetype)                   ###veryimportant
        self.is_selfdriving=is_selfdriving
    
    def selfdriving(self):
        print(f"Skoda supports self driving: {self.is_selfdriving}")

# %%
skoda1= Skoda(4,5,"petrol",True)
skoda1.selfdriving()
# Out:
# Skoda supports self driving: True

# %%
skoda1.drive()
# Out:
# the person will drive the petrol car

# %% [markdown]
# Multiple Inheritance

# %%
class Animal:
    def __init__(self,name):
        self.name=name
    def speak(self):
        print("subclass must implement this method")

class Pet:
    def __init__(self, owner):
        self.owner=owner

###Derived Class

class Dog(Animal,Pet):
    def __init__(self, name, owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)
    
    def speak(self):
        return (f"{self.name} says woof")

# %%
dog1=Dog("lucy","Baba")
#Animal.speak("vivek")
dog1.speak()
#dog1.owner
# Out:
# 'lucy says woof'

# %%
class Animal:
    def __init__(self, name, **kwargs):
        super().__init__(**kwargs)
        self.name = name
    
    def sing(self):
        return "Animal sound"
       

class Pet:
    def __init__(self, owner, **kwargs):
        super().__init__(**kwargs)
        self.owner = owner
     

class Dog(Animal, Pet):
    def __init__(self, name, owner):
        super().__init__(name=name, owner=owner)
    def speak(self):
        return (f"{self.name} says woof")

dog = Dog("Buddy", "Vivek")
dog.owner
dog.sing()
# Out:
# 'Animal sound'
